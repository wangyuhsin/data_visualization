# %%
import pandas as pd
df = pd.read_csv('data/year_ipc_count.csv')
df.head()
# Out:
#   mono_IPC  year  IPC_count
# 0        F  1980          0
# 1        F  1981          0
# 2        F  1982         55
# 3        F  1983         71
# 4        F  1984          0

# %%
from bokeh.plotting import figure, ColumnDataSource
from bokeh.models.tools import HoverTool
from bokeh.models import Select
from bokeh.layouts import widgetbox, row, column
from bokeh.transform import factor_cmap
from bokeh.palettes import Blues256, linear_palette, small_palettes
from bokeh.embed import components
from bokeh.io import output_notebook, show
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
p = figure(plot_width=1000, plot_height=400, tools='pan,wheel_zoom,save,reset',
    toolbar_location='above')
p.title.text = 'year & IPC count'

# %%
for df, label_name, color in zip([df[df['mono_IPC']=='A'], df[df['mono_IPC']=='B'], df[df['mono_IPC']=='C'], df[df['mono_IPC']=='D'], df[df['mono_IPC']=='E'], df[df['mono_IPC']=='F'], df[df['mono_IPC']=='G'], df[df['mono_IPC']=='H']], ['A_HUMAN NECESSITIES','B_PERFORMING OPERATIONS','C_CHEMISTRY; METALLURGY','D_TEXTILES; PAPER','E_FIXED CONSTRUCTIONS','F_MECHANICAL ENGINEERING','G_PHYSICS','H_ELECTRICITY'], ['#597080','#6da18a','#546799','#6699cc','#c4736c','#bd555f','#8c3f52','#66294c']):
#     x = pd.to_datetime(e['year']).tolist()
#     x = e['year'].tolist()
#     y = e['IPC_count'].tolist()
    source = ColumnDataSource(df)
    p.line(source=source, x='year', y= 'IPC_count', line_width=1.8, color=color, alpha=0.5, muted_color=color, muted_alpha=0.05, legend_label=label_name)
    
p.legend.location = 'top_left'
p.legend.click_policy='mute'
p.legend.label_text_font_size = '6pt'

p.background_fill_color='white'

hover = HoverTool(muted_policy='ignore')
hover.tooltips = [('IPC','@mono_IPC'),('Year','@year'),('Count', '@IPC_count')]
p.add_tools(hover)

show(p)
# Out:
#   <div class="bk-root" id="e2158fd5-424e-4081-8207-8ff0086e08ba" data-root-id="1002"></div>
